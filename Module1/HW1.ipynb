# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

first = 'Alex'
middle = 'Daniel'
last = 'Olteanu' 

df = pd.DataFrame({'NAMES': [first, middle, last], 'LETTERS': [len(first), len(middle), len(last)]})
df.plot.bar(x='NAMES', y='LETTERS', rot=0)
plt.show()
